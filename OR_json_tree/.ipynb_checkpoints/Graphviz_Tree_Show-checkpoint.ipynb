# %%
d=graphviz.Digraph()

# %%
d.node('OpenRefine')
d.node('Facet')
d.node('Text filter')
d.node('Edit cells')
d.node('Edit column')
d.node('Transpose')
d.node('Sort')
d.node('View')
d.node('Reconcile')

# %%
d.edge('OpenRefine','Facet')
d.edge('OpenRefine','Text filter')
d.edge('OpenRefine','Edit cells')
d.edge('OpenRefine','Edit column')
d.edge('OpenRefine','Transpose')
d.edge('OpenRefine','Sort')
d.edge('OpenRefine','View')
d.edge('OpenRefine','Reconcile')

# %%
d

# %%
d.node('Text facet')
d.node('Numeric facet')
d.node('Timeline facet')
d.node('Scatterplot facet')
d.node('Custom text facet')
d.node('Custom Numeric Facet')
d.node('Customized facets')
d.edge('Facet','Text facet')
d.edge('Facet','Numeric facet')
d.edge('Facet','Timeline facet')
d.edge('Facet','Scatterplot facet')
d.edge('Facet','Custom text facet')
d.edge('Facet','Custom Numeric Facet')
d.edge('Facet','Customized facets')

# %%
d.node('Word facet')
d.node('Duplicate facet')
d.node('Numeric log facet')
d.node('1-bounded numeric log facet')
d.node('Text length facet')
d.node('Log of text length facet')
d.node('Unicode char-code facet')
d.node('Facet by error')
d.node('Facet by blank')
d.edge('Customized facets','Word facet')
d.edge('Customized facets','Duplicate facet')
d.edge('Customized facets','Numeric log facet')
d.edge('Customized facets','1-bounded numeric log facet')
d.edge('Customized facets','Text length facet')
d.edge('Customized facets','Log of text length facet')
d.edge('Customized facets','Unicode char-code facet')
d.edge('Customized facets','Facet by error')
d.edge('Customized facets','Facet by blank')

# %%
d.node('Transform')
d.node('Common transforms')
d.node('Fill down')
d.node('Blank down')
d.node('Split multi-valued cells')
d.node('Join multi-valued cells')
d.node('Cluster and edit')
d.edge('Edit cells','Transform')
d.edge('Edit cells','Common transforms')
d.edge('Edit cells','Fill down')
d.edge('Edit cells','Blank down')
d.edge('Edit cells','Split multi-valued cells')
d.edge('Edit cells','Join multi-valued cells')
d.edge('Edit cells','Cluster and edit')

# %%
d.node('Trim leading and trailing whitespace')
d.node('Collapse consecutive whitespace')
d.node('Unescape HTML entities')
d.node('To titlecase')
d.node('To uppercase')
d.node('To lowercase')
d.node('To number')
d.node('To date')
d.node('To text')
d.node('Blank out cells')
d.edge('Common transforms','Trim leading and trailing whitespace')
d.edge('Common transforms','Collapse consecutive whitespace')
d.edge('Common transforms','Unescape HTML entities')
d.edge('Common transforms','To titlecase')
d.edge('Common transforms','To uppercase')
d.edge('Common transforms','To lowercase')
d.edge('Common transforms','To number')
d.edge('Common transforms','To date')
d.edge('Common transforms','To text')
d.edge('Common transforms','Blank out cells')

# %%
d

# %%
d.node('Split into several columns')
d.node('Add column based on this column')
d.node('Add column by fetching URLs')
d.node('Add columns from reconciled values')
d.node('Rename this column')
d.node('Remove this column')
d.node('Move column to beginning')
d.node('Move column to end')
d.node('Move column left')
d.node('Move column right')
d.edge('Edit column','Split into several columns')
d.edge('Edit column','Add column based on this column')
d.edge('Edit column','Add column by fetching URLs')
d.edge('Edit column','Add columns from reconciled values')
d.edge('Edit column','Rename this column')
d.edge('Edit column','Remove this column')
d.edge('Edit column','Move column to beginning')
d.edge('Edit column','Move column to end')
d.edge('Edit column','Move column left')
d.edge('Edit column','Move column right')

# %%
d.node('Transpose cells across columns into rows')
d.node('Transpose cells in rows into columns')
d.node('Columnize by key/value columns')
d.edge('Transpose','Transpose cells across columns into rows')
d.edge('Transpose','Transpose cells in rows into columns')
d.edge('Transpose','Columnize by key/value columns')

# %%
d.node('Collapse this column')
d.node('Collapse all other columns')
d.node('Collapse all columns to left')
d.node('Collapse all columns to right')
d.edge('View','Collapse this column')
d.edge('View','Collapse all other columns')
d.edge('View','Collapse all columns to left')
d.edge('View','Collapse all columns to right')

# %%
d.node('Start reconciling')
d.node('Facets')
d.node('QA facets')
d.node('Actions')
d.node('Copy reconciliation data')
d.edge('Reconcile','Start reconciling')
d.edge('Reconcile','Facets')
d.edge('Reconcile','QA facets')
d.edge('Reconcile','Actions')
d.edge('Reconcile','Copy reconciliation data')

# %%
d.node('By judgment')
d.node('Best candidate score')
d.node('Best candidate type match')
d.node('Best candidate name match')
d.node('Best candidate name edit distance')
d.node('Best candidate name word similarity')
d.node('Best candidate types')
d.edge('Facets','By judgment')
d.edge('Facets','Best candidate score')
d.edge('Facets','Best candidate type match')
d.edge('Facets','Best candidate name match')
d.edge('Facets','Best candidate name edit distance')
d.edge('Facets','Best candidate name word similarity')
d.edge('Facets','Best candidate types')

# %%
d.node('QA results')
d.node('Judgment actions')
d.node('Judgment history entries')
d.edge('QA facets','QA results')
d.edge('QA facets','Judgment actions')
d.edge('QA facets','Judgment history entries')

# %%
d.node('Match each cell to its best candidate')
d.node('Create a new item for each cell')
d.node('Create one new item for similar cells')
d.node('Match all filtered cells to')
d.node('Discard reconciliation judgments')
d.node('Clear reconciliatioin data')
d.edge('Actions','Match each cell to its best candidate')
d.edge('Actions','Create a new item for each cell')
d.edge('Actions','Create one new item for similar cells')
d.edge('Actions','Match all filtered cells to')
d.edge('Actions','Discard reconciliation judgments')
d.edge('Actions','Clear reconciliatioin data')

# %%
d
