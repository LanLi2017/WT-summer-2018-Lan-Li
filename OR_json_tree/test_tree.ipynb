# %%
import graphviz

# %%
d=graphviz.Digraph()

# %%
d.node('columnName')
d.node('FMID')
d.node('MarketName')
d.edge('columnName','FMID')
d.edge('columnName','MarketName')

# %%
d.node('operation1')
d.node('operation2')
d.node('operation3')
d.edge('FMID','operation1')
d.edge('FMID','operation2')
d.edge('FMID','operation3')

# %%
d.node('core/text-transform')
d.node('row-based')
d.node('value')
d.node('keep-original')
d.edge('operation1','core/text-transform')
d.edge('operation1','row-based')
d.edge('operation1','value')
d.edge('operation1','keep-original')

# %%
d.node('core/text-transform ')
d.node('row-based ')
d.node('ValuetoNumber')
d.node('keep-original ')
d.edge('operation2','core/text-transform ')
d.edge('operation2','row-based ')
d.edge('operation2','ValuetoNumber')
d.edge('operation2','keep-original ')

# %%
d.node('core/column-rename')
d.edge('operation3','core/column-rename')

# %%
d.node('core/mass-edit')
d.node('row-based  ')
d.node('value ')
d.node('edits')
d.edge('MarketName','core/mass-edit')
d.edge('MarketName','row-based  ')
d.edge('MarketName','value ')
d.edge('MarketName','edits')

# %%
d.node('fromBlank')
d.node('fromError')
d.node('from')
d.node('to')
d.edge('edits','fromBlank')
d.edge('edits','fromError')
d.edge('edits','from')
d.edge('edits','to')

# %%
d
